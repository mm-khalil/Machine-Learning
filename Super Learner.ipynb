# %% [markdown]
# ### LAB Item 1
#
# 1. Run weather regression from 1/1/2012 --> 8/1/2019 to Natural Gas Consumption.  Use the data posted in week 7 folder.
#
#     https://www.eia.gov/dnav/ng/ng_cons_sum_dcu_nus_m.htm   (original source but use data in class folder)
#
# 2. Using SkLearn, regress to sum of: U.S. Natural Gas Residential Consumption (MMcf) + Natural Gas Deliveries to Commercial Consumers (Including Vehicle Fuel through 1996) in the U.S. (MMcf)
#
# 3. What is R^2 ?
#
# 4. Estimate October 2019!  What was the residual between your estimate and the actual.

# %%
import numpy
import pandas
import sklearn
from matplotlib import pyplot as plt
# %matplotlib inline

import plotly
#import chart_studio.plotly as py
import cufflinks

import plotly.graph_objects as go
#from chart_studio.plotly import plot, iplot

# %%
temp_df = pandas.read_excel(r"C:\\Users\khalil\ML Lab 7\weather-natgas.xlsx" , sheet_name='Weather')

# %%
ng_df  = pandas.read_excel(r"C:\\Users\khalil\ML Lab 7\weather-natgas.xlsx" , sheet_name='NatGas')

# %%
temp_df.head()
# Out:
#     themonth        hdd       cdd  temp_natl
# 0 2017-01-01  23.648603  0.313590  41.664987
# 1 2017-02-01  18.392368  0.537725  47.145357
# 2 2017-03-01  16.762865  0.893394  49.130529
# 3 2017-04-01   7.544863  2.058533  59.513670
# 4 2017-05-01   4.333481  3.636984  64.303503

# %%
ng_df.tail()
# Out:
#          Date  U.S. Natural Gas Total Consumption (MMcf)  \
# 29 2019-06-01                                    2119341
# 30 2019-07-01                                    2393904
# 31 2019-08-01                                    2433924
# 32 2019-09-01                                    2206252
# 33 2019-10-01                                    2306544
#
#     U.S. Natural Gas Lease and Plant Fuel Consumption (MMcf)  \
# 29                                             147863
# 30                                             153635
# 31                                             157370
# 32                                             152877
# 33                                             159359
#
#     U.S. Natural Gas Pipeline & Distribution Use (MMcf)  \
# 29                                              68482
# 30                                              77819
# 31                                              79079
# 32                                              71327
# ...

# %%
#Q 1
temp_df['themonth'] = pandas.to_datetime(temp_df['themonth'])
ng_df['Date'] = pandas.to_datetime(ng_df['Date'])

# %%
m_df = temp_df.merge(ng_df, left_on=['themonth'], right_on=['Date'])
m_df['ones'] = 1
m_df.tail()
# Out:
#      themonth       hdd        cdd  temp_natl       Date  \
# 29 2019-06-01  0.668620   7.894777  72.226157 2019-06-01
# 30 2019-07-01  0.041155  12.464210  77.423055 2019-07-01
# 31 2019-08-01  0.081061  11.162419  76.081358 2019-08-01
# 32 2019-09-01  0.916233   8.597273  72.681040 2019-09-01
# 33 2019-10-01  7.809861   2.738358  59.928497 2019-10-01
#
#     U.S. Natural Gas Total Consumption (MMcf)  \
# 29                                    2119341
# 30                                    2393904
# 31                                    2433924
# 32                                    2206252
# 33                                    2306544
#
#     U.S. Natural Gas Lease and Plant Fuel Consumption (MMcf)  \
# 29                                             147863
# 30                                             153635
# 31                                             157370
# 32                                             152877
# 33                                             159359
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(m_df[['temp_natl']], m_df[['U.S. Natural Gas Residential Consumption (MMcf)']])

# %%
reg_pred = reg.predict(m_df[['temp_natl']])

# %%
 reg_pred
# Out:
# array([[747301.84536559],
#        [633923.42721053],
#        [592854.00184443],
#        [378046.59130379],
#        [278954.06474044],
#        [103374.19714355],
#        [ 19077.88536711],
#        [ 68321.49182395],
#        [153367.32439739],
#        [331123.03461784],
#        [567732.63450156],
#        [789686.9477938 ],
#        [842172.31205872],
#        [690456.08603829],
#        [640624.48243962],
#        [504892.20002534],
#        [188766.31506553],
#        [ 84719.53467095],
#        [  9170.22302468],
#        [ 27304.27291418],
#        [125760.30241701],
#        [373801.70779288],
#        [648919.75467068],
#        [731754.80843373],
#        [827197.66801059],
#        [763260.89239024],
#        [656009.01771917],
#        [412463.78947712],
#        [263690.12103614],
#        [115049.45480311],
#        [  7535.5298118 ],
#        [ 35292.68062875],
#        [105638.78502264],
#        [369464.61543885]])

# %%
reg.score(m_df[['temp_natl']], m_df[['U.S. Natural Gas Residential Consumption (MMcf)']])
# Out:
# 0.9356485366095912

# %%
#Q 2
m_df['rescomm'] = m_df['Natural Gas Deliveries to Commercial Consumers (Including Vehicle Fuel through 1996) in the U.S. (MMcf)'] + m_df['U.S. Natural Gas Residential Consumption (MMcf)']

# %%
m_df.tail()
# Out:
#      themonth       hdd        cdd  temp_natl       Date  \
# 29 2019-06-01  0.668620   7.894777  72.226157 2019-06-01
# 30 2019-07-01  0.041155  12.464210  77.423055 2019-07-01
# 31 2019-08-01  0.081061  11.162419  76.081358 2019-08-01
# 32 2019-09-01  0.916233   8.597273  72.681040 2019-09-01
# 33 2019-10-01  7.809861   2.738358  59.928497 2019-10-01
#
#     U.S. Natural Gas Total Consumption (MMcf)  \
# 29                                    2119341
# 30                                    2393904
# 31                                    2433924
# 32                                    2206252
# 33                                    2306544
#
#     U.S. Natural Gas Lease and Plant Fuel Consumption (MMcf)  \
# 29                                             147863
# 30                                             153635
# 31                                             157370
# 32                                             152877
# 33                                             159359
#
# ...

# %%
#Q 3
m_df['temp_natl_sq'] = m_df['temp_natl'] **2 #square temperature

# %%
reg1 = LinearRegression().fit(m_df[['temp_natl']], m_df[['rescomm']])

# %%
reg_pred = reg.predict(m_df[['temp_natl']])

# %%
reg_pred
# Out:
# array([[747301.84536559],
#        [633923.42721053],
#        [592854.00184443],
#        [378046.59130379],
#        [278954.06474044],
#        [103374.19714355],
#        [ 19077.88536711],
#        [ 68321.49182395],
#        [153367.32439739],
#        [331123.03461784],
#        [567732.63450156],
#        [789686.9477938 ],
#        [842172.31205872],
#        [690456.08603829],
#        [640624.48243962],
#        [504892.20002534],
#        [188766.31506553],
#        [ 84719.53467095],
#        [  9170.22302468],
#        [ 27304.27291418],
#        [125760.30241701],
#        [373801.70779288],
#        [648919.75467068],
#        [731754.80843373],
#        [827197.66801059],
#        [763260.89239024],
#        [656009.01771917],
#        [412463.78947712],
#        [263690.12103614],
#        [115049.45480311],
#        [  7535.5298118 ],
#        [ 35292.68062875],
#        [105638.78502264],
#        [369464.61543885]])

# %%
reg.score(m_df[['temp_natl']], m_df[['rescomm']])
# Out:
# 0.43281248829561114

# %%
#Q 4
temp_df = pandas.read_excel(r"C:\\Users\khalil\ML Lab 7\weather-natgas.xlsx" , sheet_name='Weather')

# %%
ng_df  = pandas.read_excel(r"C:\\Users\khalil\ML Lab 7\weather-natgas.xlsx" , sheet_name='NatGas')

# %%
temp_df.tail()
# Out:
#      themonth        hdd        cdd  temp_natl
# 30 2019-07-01   0.041155  12.464210  77.423055
# 31 2019-08-01   0.081061  11.162419  76.081358
# 32 2019-09-01   0.916233   8.597273  72.681040
# 33 2019-10-01   7.809861   2.738358  59.928497
# 34 2019-11-01  18.480750   0.573533  47.092783

# %%
ng_df.tail()
# Out:
#          Date  U.S. Natural Gas Total Consumption (MMcf)  \
# 29 2019-06-01                                    2119341
# 30 2019-07-01                                    2393904
# 31 2019-08-01                                    2433924
# 32 2019-09-01                                    2206252
# 33 2019-10-01                                    2306544
#
#     U.S. Natural Gas Lease and Plant Fuel Consumption (MMcf)  \
# 29                                             147863
# 30                                             153635
# 31                                             157370
# 32                                             152877
# 33                                             159359
#
#     U.S. Natural Gas Pipeline & Distribution Use (MMcf)  \
# 29                                              68482
# 30                                              77819
# 31                                              79079
# 32                                              71327
# ...

# %%
temp_df['themonth'] = pandas.to_datetime(temp_df['themonth'])
ng_df['Date'] = pandas.to_datetime(ng_df['Date'])

# %%
m_df = temp_df.merge(ng_df, left_on=['themonth'], right_on=['Date'])
m_df['ones'] = 1
m_df.tail()
# Out:
#      themonth       hdd        cdd  temp_natl       Date  \
# 29 2019-06-01  0.668620   7.894777  72.226157 2019-06-01
# 30 2019-07-01  0.041155  12.464210  77.423055 2019-07-01
# 31 2019-08-01  0.081061  11.162419  76.081358 2019-08-01
# 32 2019-09-01  0.916233   8.597273  72.681040 2019-09-01
# 33 2019-10-01  7.809861   2.738358  59.928497 2019-10-01
#
#     U.S. Natural Gas Total Consumption (MMcf)  \
# 29                                    2119341
# 30                                    2393904
# 31                                    2433924
# 32                                    2206252
# 33                                    2306544
#
#     U.S. Natural Gas Lease and Plant Fuel Consumption (MMcf)  \
# 29                                             147863
# 30                                             153635
# 31                                             157370
# 32                                             152877
# 33                                             159359
#
# ...

# %%
reg = LinearRegression().fit(m_df[['temp_natl']], m_df[['U.S. Natural Gas Residential Consumption (MMcf)']])

# %%
reg_pred2 = reg.predict(m_df[['temp_natl']])

# %%
# reg_pred

# %%
reg.score(m_df[['temp_natl']], m_df[['U.S. Natural Gas Residential Consumption (MMcf)']])
# Out:
# 0.9356485366095912

# %% [markdown]
# ### LAB Item 2
#
# 1. Run the same calculation as LAB Item 1 using the python statsmodels package
#
# import statsmodels.api as sm
#
# mod = sm.OLS(Y, X)
#
# res = mod.fit()

# %%
import statsmodels.formula.api as smf
import numpy as np

# %%
# Q 1
df = pd.DataFrame(m_df) 

x = df[['temp_natl','U.S. Natural Gas Residential Consumption (MMcf)']]
y = df['temp_natl']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predictions = model.predict(x) 

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              temp_natl   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.292e+23
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        09:56:05   Log-Likelihood:                 736.96
# No. Observations:                  34   AIC:                            -1468.
# Df Residuals:                      31   BIC:                            -1463.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Q 2
m_df['rescomm'] = m_df['Natural Gas Deliveries to Commercial Consumers (Including Vehicle Fuel through 1996) in the U.S. (MMcf)'] + m_df['U.S. Natural Gas Residential Consumption (MMcf)']

# %%
m_df['temp_natl_sq'] = m_df['temp_natl'] **2 #square temperature

# %%
df1 = pd.DataFrame(m_df) 

x = df1[['temp_natl','rescomm']]
y = df1['temp_natl']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predictions = model.predict(x) 

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              temp_natl   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.472e+23
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        10:10:19   Log-Likelihood:                 748.45
# No. Observations:                  34   AIC:                            -1491.
# Df Residuals:                      31   BIC:                            -1486.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.035e-10   2.83e-10     -0.366      0.717    -6.8e-10    4.73e-10
# ...

# %%
# Q 3
import statsmodels.api as sm
model = sm.OLS(m_df[['U.S. Natural Gas Residential Consumption (MMcf)']], m_df[['temp_natl', 'ones']])
results = model.fit()
results.params
# Out:
# temp_natl   -2.068810e+04
# ones         1.609271e+06
# dtype: float64

# %%
print(results.summary())
# Out:
#                                            OLS Regression Results
# ...
# Dep. Variable:     U.S. Natural Gas Residential Consumption (MMcf)   R-squared:                       0.936
# Model:                                                         OLS   Adj. R-squared:                  0.934
# Method:                                              Least Squares   F-statistic:                     465.3
# Date:                                             Wed, 01 Mar 2023   Prob (F-statistic):           1.25e-20
# Time:                                                     20:35:32   Log-Likelihood:                -429.37
# No. Observations:                                               34   AIC:                             862.7
# Df Residuals:                                                   32   BIC:                             865.8
# Df Model:                                                        1
# Covariance Type:                                         nonrobust
# ...

# %%
# Q 4
temp_df = pandas.read_excel(r"C:\\Users\khalil\ML Lab 7\weather-natgas.xlsx" , sheet_name='Weather')
ng_df  = pandas.read_excel(r"C:\\Users\khalil\ML Lab 7\weather-natgas.xlsx" , sheet_name='NatGas')

# %%
temp_df['themonth'] = pandas.to_datetime(temp_df['themonth'])
ng_df['Date'] = pandas.to_datetime(ng_df['Date'])

# %%
m_df1 = temp_df.merge(ng_df, left_on=['themonth'], right_on=['Date'])
m_df1['ones'] = 1
m_df1.tail()
# Out:
#      themonth       hdd        cdd  temp_natl       Date  \
# 29 2019-06-01  0.668620   7.894777  72.226157 2019-06-01
# 30 2019-07-01  0.041155  12.464210  77.423055 2019-07-01
# 31 2019-08-01  0.081061  11.162419  76.081358 2019-08-01
# 32 2019-09-01  0.916233   8.597273  72.681040 2019-09-01
# 33 2019-10-01  7.809861   2.738358  59.928497 2019-10-01
#
#     U.S. Natural Gas Total Consumption (MMcf)  \
# 29                                    2119341
# 30                                    2393904
# 31                                    2433924
# 32                                    2206252
# 33                                    2306544
#
#     U.S. Natural Gas Lease and Plant Fuel Consumption (MMcf)  \
# 29                                             147863
# 30                                             153635
# 31                                             157370
# 32                                             152877
# 33                                             159359
#
# ...

# %%
df2 = pd.DataFrame(m_df1) 

x = df[['temp_natl','rescomm']]
y = df['temp_natl']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()
predictions = model.predict(x) 

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              temp_natl   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.472e+23
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        10:10:50   Log-Likelihood:                 748.45
# No. Observations:                  34   AIC:                            -1491.
# Df Residuals:                      31   BIC:                            -1486.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.035e-10   2.83e-10     -0.366      0.717    -6.8e-10    4.73e-10
# ...

# %% [markdown]
# ### LAB Item 3
#
# Return to previous dataset: Adult income
# https://www.kaggle.com/wenruliu/adult-income-dataset
#
# Build a logistic Regression targeting income above / below 50k...
#
# Review Example.

# %%
import postgresql
import pandas as pd

# %%
df = pandas.read_csv(r'C:\Users\khalil\ML Lab 7\adult.csv')

# %%
# Let's use a little Encoding magic.....we'll come back to this later.
for column in df.columns:
    if df[column].dtype == type(object):
        le = sklearn.preprocessing.LabelEncoder()
        df[column] = le.fit_transform(df[column])

# %%
x_df = df.drop(columns=['income'])    # We want everything but the response variable...in this case income
y_df = df[['income']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(random_state=16)
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_test)

y_pred
# Out:
# C:\Users\khalil\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# array([0, 0, 1, ..., 0, 0, 0])

# %%
print('Accuracy: {:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# Accuracy: 0.80

# %% [markdown]
# ### LAB Item 4: Let's take a look at the sklearn California housing dataset from previous weeks
#
# ... A)  review a multivariate regression from this week's content (built in class notes)
#
# ... B) Compare the results from the multivariate linear regression to a random forest by building a RF.  You've built a random forest on this dataset before.  Note the differences in model accuracy between the linear regression and RF.

# %%
# B Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv(r'C:\Users\khalil\ML HW 3\housing.csv')
df = pd.DataFrame(data)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = df.drop('ocean_proximity', axis=1)

# %%
df = df.dropna()

# %%
x_df = df.drop(columns=['median_house_value'])    
y_df = df[['median_house_value']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df)

# %%
rf = RandomForestClassifier(n_estimators=5) #100 is no of trees
rf.fit(x_train, y_train)
# Out:
# C:\Users\khalil\AppData\Local\Temp/ipykernel_6748/2074487705.py:2: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6748/2074487705.py in <module>
#       1 rf = RandomForestClassifier(n_estimators=5) #100 is no of trees
# ----> 2 rf.fit(x_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     385             # parallel_backend contexts set at a higher level,
#     386             # since correctness does not rely on using threads.
# --> 387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     388                              **_joblib_parallel_args(prefer='threads'))(
# ...

# %%
pred_df = pd.DataFrame(rf.predict(X_test), columns=['pred'])
pred_df['actual'] = y_test.values
pred_df['residual'] = (pred_df['pred'] - pred_df['actual']).abs()
pred_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6748/3488279276.py in <module>
# ----> 1 pred_df = pd.DataFrame(rf.predict(X_test), columns=['pred'])
#       2 pred_df['actual'] = y_test.values
#       3 pred_df['residual'] = (pred_df['pred'] - pred_df['actual']).abs()
#       4 pred_df
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     628             The predicted classes.
#     629         """
# --> 630         proba = self.predict_proba(X)
#     631
#     632         if self.n_outputs_ == 1:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     672         check_is_fitted(self)
#     673         # Check data
# --> 674         X = self._validate_X_predict(X)
#     675
#     676         # Assign chunk of trees to jobs
#
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(pred_df['actual'], pred_df['pred'])

# %% [markdown]
# Sorry Professor As my system is not able to Allocate much memory and it again and again crashes Python File, thats why I am not able to see and Compare accuracies of Random Forest with Linear Regression
